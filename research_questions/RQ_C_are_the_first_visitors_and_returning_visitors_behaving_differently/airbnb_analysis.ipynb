# %%
import geopandas as gpd
import pandas as pd

# %%
# read csv file 

reviews = pd.read_csv('../../dataset/airbnb/reviews_complete.csv')

# %%
reviews.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0       13131   32583962  2015-05-19     10395756          Juan
# 1       13131   79179418  2016-06-11     33583317         Annie
# 2       13131   97734954  2016-08-28      5834919     Katherine
# 3       13131  108353272  2016-10-15     49771730      Chin Wai
# 4       13131  204651070  2017-10-19    112577092          Erin
#
#                                             comments
# 0  A unique place to say the least.  Such a pleas...
# 1  We had a fabulous time in the green windmill f...
# 2  FANTASTIC!!! Quintessential Airbnb experience....
# 3  The owner greet us once we had arrived and ext...
# 4  Nikos’s place is fantastic! The quality of the...

# %%
# check if there are duplicates reviewer_id
reviews.duplicated(subset=['reviewer_id']).sum()
# Out:
# 43677

# %%
# open listings as geodataframe
listings = gpd.read_file('../../dataset/airbnb/reviews_complete.csv',crs='EPSG:4326')
listings = gpd.GeoDataFrame(listings,crs='EPSG:4326',geometry=gpd.points_from_xy(listings.longitude, listings.latitude))
listings = listings.cx[25.3:25.5, 36.3:36.5]

# %%
listings.head()
# Out:
#        id                                name host_id  \
# 0   13131                      Green Windmill   50838
# 1   13443                Lilac Windmill Villa   50838
# 10  48289  cavehouse  with caldera sunsetview  219945
# 15  78178  Apartments in Firostefani- sunrise   51279
# 16  78182   Apartments in Firostefani- Garden   51279
#
#                   host_name neighbourhood_group      neighbourhood  latitude  \
# 0                     Nikos                      Θήρας (Santorini)  36.45351
# 1                     Nikos                      Θήρας (Santorini)  36.45304
# 10                   Ioanna                      Θήρας (Santorini)  36.46203
# 15  Travel & Tourism Greece                      Θήρας (Santorini)  36.42499
# 16  Travel & Tourism Greece                      Θήρας (Santorini)  36.42536
#
#    longitude        room_type price minimum_nights number_of_reviews  \
# 0   25.43316  Entire home/apt   280              2                 7
# 1   25.43263  Entire home/apt   252              2                10
# 10  25.37248  Entire home/apt   170              2               176
# 15  25.42974     Private room   110              2                56
# 16  25.42928     Private room   135              2                53
#
#    last_review reviews_per_month calculated_host_listings_count  \
# 0   2019-07-05              0.13                              3
# 1   2018-04-09              0.17                              3
# 10  2019-09-23              1.94                              3
# 15  2019-06-12              0.56                             54
# 16  2019-08-30              0.53                             54
#
#    availability_365                   geometry
# 0               202  POINT (25.43316 36.45351)
# 1               209  POINT (25.43263 36.45304)
# 10              147  POINT (25.37248 36.46203)
# 15               13  POINT (25.42974 36.42499)
# 16               10  POINT (25.42928 36.42536)

# %%
# convert column in int type

listings['id'] = listings['id'].astype(int)
reviews['listing_id'] = reviews['listing_id'].astype(int)

listings = listings.merge(reviews, left_on='id', right_on='listing_id')

# %%
# select only reviewers with more than 1 review

returning_visitors = listings.groupby('reviewer_id').filter(lambda x: len(x) > 1)

# %%
returning_visitors.head()
# Out:
#      id_x                                name host_id host_name  \
# 1   13131                      Green Windmill   50838     Nikos
# 11  13443                Lilac Windmill Villa   50838     Nikos
# 31  48289  cavehouse  with caldera sunsetview  219945    Ioanna
# 38  48289  cavehouse  with caldera sunsetview  219945    Ioanna
# 72  48289  cavehouse  with caldera sunsetview  219945    Ioanna
#
#    neighbourhood_group      neighbourhood  latitude longitude  \
# 1                       Θήρας (Santorini)  36.45351  25.43316
# 11                      Θήρας (Santorini)  36.45304  25.43263
# 31                      Θήρας (Santorini)  36.46203  25.37248
# 38                      Θήρας (Santorini)  36.46203  25.37248
# 72                      Θήρας (Santorini)  36.46203  25.37248
#
#           room_type price  ... reviews_per_month  \
# 1   Entire home/apt   280  ...              0.13
# 11  Entire home/apt   252  ...              0.17
# 31  Entire home/apt   170  ...              1.94
# 38  Entire home/apt   170  ...              1.94
# 72  Entire home/apt   170  ...              1.94
#
#    calculated_host_listings_count availability_365                   geometry  \
# 1                               3              202  POINT (25.43316 36.45351)
# 11                              3              209  POINT (25.43263 36.45304)
# 31                              3              147  POINT (25.37248 36.46203)
# 38                              3              147  POINT (25.37248 36.46203)
# 72                              3              147  POINT (25.37248 36.46203)
#
#    listing_id      id_y        date  reviewer_id  reviewer_name  \
# 1       13131  79179418  2016-06-11     33583317          Annie
# 11      13443  53345473  2015-11-08     13071990           Igor
# 31      48289   7818122  2013-10-04      8884745           Ming
# 38      48289  16194360  2014-07-23       645767         Cédric
# 72      48289  74153524  2016-05-13     28483361           Chen
#
#                                              comments
# 1   We had a fabulous time in the green windmill f...
# 11  Definitely a wonderful stay at the lilac windm...
# 31  We spent two wonderful days in Ioanna 's apart...
# 38  The reservation was canceled 18 days before ar...
# 72  Mr. Fotinos' cave house is clean and decorated...
#
# [5 rows x 23 columns]

# %%
# order by reviewer_id and date

returning_visitors = returning_visitors.sort_values(by=['reviewer_id','date'])

# %%
returning_visitors.head()
# Out:
#            id_x                              name    host_id  \
# 33775   6002904    LA MER CAVE HOUSE-VOLCANO VIEW    3867239
# 62211  13635039                ARGITHEA APARTMENT    3867239
# 1658     163832  "Gravitate" caldera luxury view!     665681
# 28219   4562213         Nicoletta Ammoudi Suite B    5044938
# 78958  20144115            Santa Rinoula Suites 1  136239977
#
#                              host_name neighbourhood_group      neighbourhood  \
# 33775                            Maria                      Θήρας (Santorini)
# 62211                            Maria                      Θήρας (Santorini)
# 1658                       Sensyo Home                      Θήρας (Santorini)
# 28219  Nicoletta, Christina, Alexandra                      Θήρας (Santorini)
# 78958                        Dimitrios                      Θήρας (Santorini)
#
#        latitude longitude        room_type price  ... reviews_per_month  \
# 33775   36.4614  25.37409  Entire home/apt   180  ...              3.85
# 62211  36.46072  25.37461  Entire home/apt   220  ...              3.65
# 1658   36.42604  25.42784  Entire home/apt   130  ...              2.31
# 28219  36.46148  25.37092  Entire home/apt   130  ...              2.90
# 78958  36.37492  25.42409     Private room   535  ...              2.24
#
#       calculated_host_listings_count availability_365  \
# 33775                             28              346
# 62211                             28              324
# 1658                               4              182
# 28219                             18              148
# 78958                              3                4
#
#                         geometry listing_id       id_y        date  \
# 33775  POINT (25.37409 36.46140)    6002904  103587213  2016-09-23
# 62211  POINT (25.37461 36.46072)   13635039  103722162  2016-09-24
# 1658   POINT (25.42784 36.42604)     163832   99771161  2016-09-05
# 28219  POINT (25.37092 36.46148)    4562213  100357406  2016-09-08
# 78958  POINT (25.42409 36.37492)   20144115  318702058  2018-09-04
#
#        reviewer_id  reviewer_name  \
# 33775         3840      Christine
# 62211         3840      Christine
# 1658         15176        Charlie
# 28219        15176        Charlie
# 78958        44934         Darren
#
#                                                 comments
# 33775  the host is very responsive via airbnb app and...
# 62211  the host was very responsive via airbnb app be...
# 1658   "Gravitate" was the first place we landed at t...
# 28219  As you can see in the photos, the location is ...
# 78958  Dimitrios and Eirini’s place was beyond our ex...
#
# [5 rows x 23 columns]

# %%
# convert date in datetime

returning_visitors['date'] = pd.to_datetime(returning_visitors['date'])

# compute the time between the first and the second review
returning_visitors['time_between_reviews'] = returning_visitors.groupby('reviewer_id')['date'].diff()

# %%
returning_visitors.head()
# Out:
#            id_x                              name    host_id  \
# 33775   6002904    LA MER CAVE HOUSE-VOLCANO VIEW    3867239
# 62211  13635039                ARGITHEA APARTMENT    3867239
# 1658     163832  "Gravitate" caldera luxury view!     665681
# 28219   4562213         Nicoletta Ammoudi Suite B    5044938
# 78958  20144115            Santa Rinoula Suites 1  136239977
#
#                              host_name neighbourhood_group      neighbourhood  \
# 33775                            Maria                      Θήρας (Santorini)
# 62211                            Maria                      Θήρας (Santorini)
# 1658                       Sensyo Home                      Θήρας (Santorini)
# 28219  Nicoletta, Christina, Alexandra                      Θήρας (Santorini)
# 78958                        Dimitrios                      Θήρας (Santorini)
#
#        latitude longitude        room_type price  ...  \
# 33775   36.4614  25.37409  Entire home/apt   180  ...
# 62211  36.46072  25.37461  Entire home/apt   220  ...
# 1658   36.42604  25.42784  Entire home/apt   130  ...
# 28219  36.46148  25.37092  Entire home/apt   130  ...
# 78958  36.37492  25.42409     Private room   535  ...
#
#       calculated_host_listings_count availability_365  \
# 33775                             28              346
# 62211                             28              324
# 1658                               4              182
# 28219                             18              148
# 78958                              3                4
#
#                         geometry listing_id       id_y       date reviewer_id  \
# 33775  POINT (25.37409 36.46140)    6002904  103587213 2016-09-23        3840
# 62211  POINT (25.37461 36.46072)   13635039  103722162 2016-09-24        3840
# 1658   POINT (25.42784 36.42604)     163832   99771161 2016-09-05       15176
# 28219  POINT (25.37092 36.46148)    4562213  100357406 2016-09-08       15176
# 78958  POINT (25.42409 36.37492)   20144115  318702058 2018-09-04       44934
#
#        reviewer_name                                           comments  \
# 33775      Christine  the host is very responsive via airbnb app and...
# 62211      Christine  the host was very responsive via airbnb app be...
# 1658         Charlie  "Gravitate" was the first place we landed at t...
# 28219        Charlie  As you can see in the photos, the location is ...
# 78958         Darren  Dimitrios and Eirini’s place was beyond our ex...
#
#       time_between_reviews
# 33775                  NaT
# 62211               1 days
# 1658                   NaT
# 28219               3 days
# 78958                  NaT
#
# [5 rows x 24 columns]

# %%
# select only reviewers with a time between the first and the second review > 30 days maintaining the first review

returning_visitors_one_month = returning_visitors[returning_visitors['time_between_reviews'] > '365 days']

# %%
returning_visitors_one_month.head()
# Out:
#            id_x                                 name    host_id  \
# 59176  13235351            Offer Apartment Santorini     434714
# 39691   6860527           VILLA MATILDE-VOLCANO VIEW    3867239
# 57684  13035809  The 'Top Caldera view' villa in Oia    3197377
# 13017    972466         Villa Fegari, Thea apartment    4173986
# 82390  22706829                        INO HOTEL A08  162972715
#
#                 host_name neighbourhood_group      neighbourhood  latitude  \
# 59176  Kelenis Apartments                      Θήρας (Santorini)  36.41201
# 39691               Maria                      Θήρας (Santorini)  36.46134
# 57684          Fanis&Tina                      Θήρας (Santorini)   36.4616
# 13017             Yiannis                      Θήρας (Santorini)  36.42533
# 82390              Dorina                      Θήρας (Santorini)  36.37764
#
#       longitude        room_type price  ... calculated_host_listings_count  \
# 59176  25.44525       Hotel room    55  ...                              5
# 39691  25.37315  Entire home/apt   380  ...                             28
# 57684  25.37408  Entire home/apt   700  ...                             13
# 13017  25.42872       Hotel room   280  ...                             13
# 82390  25.48551       Hotel room    60  ...                             20
#
#       availability_365                   geometry listing_id       id_y  \
# 59176                0  POINT (25.44525 36.41201)   13235351  330081994
# 39691              320  POINT (25.37315 36.46134)    6860527  202812735
# 57684              216  POINT (25.37408 36.46160)   13035809  268210374
# 13017              240  POINT (25.42872 36.42533)     972466   67881522
# 82390              235  POINT (25.48551 36.37764)   22706829  531270917
#
#             date reviewer_id   reviewer_name  \
# 59176 2018-09-30      446104  IAN And GLYNIS
# 39691 2017-10-13      558095            Eric
# 57684 2018-05-24      738047           Tanya
# 13017 2016-04-01      803005         Brandon
# 82390 2019-09-17      944962           Foris
#
#                                                 comments time_between_reviews
# 59176  We stayed two nights at Kelenis - this place i...            1465 days
# 39691  This was out second stay at one of Maria's San...            1494 days
# 57684  Fanis & Tina's place is breath taking. Amidst ...            1029 days
# 13017  Yiannis was the best host! Easy to communicate...            1642 days
# 82390  The best place to stay in Santorini! sparkling...            1495 days
#
# [5 rows x 24 columns]

# %%
# select from returning_visitors only reviewer_id in returning_visitors_one_month

returning_visitors = returning_visitors[returning_visitors['reviewer_id'].isin(returning_visitors_one_month['reviewer_id'])]

# %%
returning_visitors.head()
# Out:
#            id_x                                 name  host_id  \
# 8739     775712  Double Studio in Karterados village  4091774
# 59176  13235351            Offer Apartment Santorini   434714
# 6456     739427          VILLA KALLISTI-VOLCANO VIEW  3867239
# 39691   6860527           VILLA MATILDE-VOLCANO VIEW  3867239
# 23716   3080829      FAMILY FRIENDLY, BOUTIQUE HOTEL  4906441
#
#                 host_name neighbourhood_group      neighbourhood  latitude  \
# 8739                Helen                      Θήρας (Santorini)  36.41179
# 59176  Kelenis Apartments                      Θήρας (Santorini)  36.41201
# 6456                Maria                      Θήρας (Santorini)  36.46086
# 39691               Maria                      Θήρας (Santorini)  36.46134
# 23716               Maria                      Θήρας (Santorini)  36.35967
#
#       longitude        room_type price  ... calculated_host_listings_count  \
# 8739   25.44721  Entire home/apt    80  ...                             10
# 59176  25.44525       Hotel room    55  ...                              5
# 6456   25.37466  Entire home/apt   250  ...                             28
# 39691  25.37315  Entire home/apt   380  ...                             28
# 23716  25.40123  Entire home/apt    38  ...                             24
#
#       availability_365                   geometry listing_id       id_y  \
# 8739               164  POINT (25.44721 36.41179)     775712   20224739
# 59176                0  POINT (25.44525 36.41201)   13235351  330081994
# 6456               330  POINT (25.37466 36.46086)     739427    7204639
# 39691              320  POINT (25.37315 36.46134)    6860527  202812735
# 23716              151  POINT (25.40123 36.35967)    3080829   40346459
#
#             date reviewer_id   reviewer_name  \
# 8739  2014-09-26      446104  IAN And GLYNIS
# 59176 2018-09-30      446104  IAN And GLYNIS
# 6456  2013-09-10      558095            Eric
# 39691 2017-10-13      558095            Eric
# 23716 2015-07-30      738047           Tanya
#
#                                                 comments time_between_reviews
# 8739   Helen was very welcoming and helpful with her ...                  NaT
# 59176  We stayed two nights at Kelenis - this place i...            1465 days
# 6456   Wow!\r\n\r\nVilla Kallisti is exactly what you...                  NaT
# 39691  This was out second stay at one of Maria's San...            1494 days
# 23716  The Rodakas Family Hotel is perfect! It looks ...                  NaT
#
# [5 rows x 24 columns]

# %%
# list unique reviewer_id

reviewer_id = returning_visitors['reviewer_id'].unique()
print(len(reviewer_id))
# Out:
# 217

# %%
import folium

# %%
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen']
i = 0
m = folium.Map(location=[returning_visitors.geometry.y.mean(), returning_visitors.geometry.x.mean()], zoom_start=12)

for idx, c in zip(reviewer_id[0:10], colors):
    # Get the color based on the value column
    color = colors[i]
    
    # Create a custom icon for the marker based on color
    icon = folium.Icon(color=color, icon='user')
    
    # Add marker with custom icon to the map

    m = returning_visitors[returning_visitors['reviewer_id']==idx][['id_x','geometry','reviewer_id']].explore(marker_type='marker',marker_kwds={'icon': icon}, m=m)
    
    i += 1
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85fb5bd8c214e01d973544570d2f3c39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;

# %%
# compute a distance column between listings reviewed by the same reviewer without geopy

returning_visitors['distance'] = returning_visitors.groupby('reviewer_id')['geometry'].apply(lambda x: x.distance(x.shift()))
# Out:
# /tmp/ipykernel_59055/2298476206.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   returning_visitors['distance'] = returning_visitors.groupby('reviewer_id')['geometry'].apply(lambda x: x.distance(x.shift()))

# %%
print(returning_visitors['distance'].max(), returning_visitors['distance'].min())
# Out:
# 0.14747739657317205 0.0

# %%
import matplotlib.pyplot as plt

# %%
import random

# %%
different_behavior = returning_visitors[returning_visitors['distance'] > 0.1]

print(different_behavior['reviewer_id'].nunique())

# list 24 different colors

colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen']

i = 0
m = folium.Map(location=[returning_visitors.geometry.y.mean(), returning_visitors.geometry.x.mean()], zoom_start=12)
reviewer_id_similar = different_behavior['reviewer_id'].unique()


for idx, c in zip(reviewer_id_similar[3:6], colors):
    # Get the color based on the value column
    color = colors[i]
    
    # Create a custom icon for the marker based on color
    icon = folium.Icon(color=color, icon='user')
    
    # Add marker with custom icon to the map

    m = returning_visitors[returning_visitors['reviewer_id']==idx][['id_x','geometry','reviewer_id']].explore(marker_type='marker',marker_kwds={'icon': icon}, m=m)
    #m = similar_behavior[similar_behavior['reviewer_id']==idx][['id_x','geometry','reviewer_id']].explore(marker_type='circle_marker',marker_kwds={'radius':10, 'fill':True}, m=m, style_kwds={'fillColor': color, 'fillOcacity': 1.0, 'color':color, 'weight':1})
    
    i += 1
    
m
# Out:
# 19
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8317a93c2c1889bf9bbddeeb3ffa3ccb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8317a93c2c1889bf9bbddeeb3ffa3ccb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8317a93c2c1889bf9bbddeeb3ffa3ccb = L.map(
#                 &quot;map_8317a93c2c1889bf9bbddeeb3ffa3ccb&quot;,
#                 {
#                     center: [36.4206967940552, 25.41935647558386],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_133e51a52d5a40893360aca6d8d21dc4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8317a93c2c1889bf9bbddeeb3ffa3ccb);
#
#
#         function geo_json_a7722806dd9c1db3eddbb378b69be985_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a7722806dd9c1db3eddbb378b69be985_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a7722806dd9c1db3eddbb378b69be985_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             const iconOptions = {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             const iconRootAlias = L.AwesomeMarkers
#             opts.icon = new iconRootAlias.Icon(iconOptions)
#
#             let style = geo_json_a7722806dd9c1db3eddbb378b69be985_styler(feature)
#             Object.assign(opts.icon.options, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_a7722806dd9c1db3eddbb378b69be985_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a7722806dd9c1db3eddbb378b69be985.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a7722806dd9c1db3eddbb378b69be985_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a7722806dd9c1db3eddbb378b69be985 = L.geoJson(null, {
#                 onEachFeature: geo_json_a7722806dd9c1db3eddbb378b69be985_onEachFeature,
#
#                 style: geo_json_a7722806dd9c1db3eddbb378b69be985_styler,
#                 pointToLayer: geo_json_a7722806dd9c1db3eddbb378b69be985_pointToLayer
#         });
#
#         function geo_json_a7722806dd9c1db3eddbb378b69be985_add (data) {
#             geo_json_a7722806dd9c1db3eddbb378b69be985
#                 .addData(data)
#                 .addTo(map_8317a93c2c1889bf9bbdde

# %%
similar_behavior = returning_visitors[returning_visitors['distance'] < 0.001]

print(similar_behavior['reviewer_id'].nunique())

# list 24 different colors

colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen']

i = 0
m = folium.Map(location=[returning_visitors.geometry.y.mean(), returning_visitors.geometry.x.mean()], zoom_start=12)
reviewer_id_similar = similar_behavior['reviewer_id'].unique()


for idx, c in zip(reviewer_id_similar[15:20], colors):
    # Get the color based on the value column
    color = colors[i]
    
    # Create a custom icon for the marker based on color
    icon = folium.Icon(color=color, icon='user')
    
    # Add marker with custom icon to the map

    m = returning_visitors[returning_visitors['reviewer_id']==idx][['id_x','geometry','reviewer_id']].explore(marker_type='marker',marker_kwds={'icon': icon}, m=m)
    #m = similar_behavior[similar_behavior['reviewer_id']==idx][['id_x','geometry','reviewer_id']].explore(marker_type='circle_marker',marker_kwds={'radius':10, 'fill':True}, m=m, style_kwds={'fillColor': color, 'fillOcacity': 1.0, 'color':color, 'weight':1})
    
    i += 1
    
m
# Out:
# 42
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71a0da2b7d69c1b5fa6f4fd77c22fbe3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71a0da2b7d69c1b5fa6f4fd77c22fbe3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71a0da2b7d69c1b5fa6f4fd77c22fbe3 = L.map(
#                 &quot;map_71a0da2b7d69c1b5fa6f4fd77c22fbe3&quot;,
#                 {
#                     center: [36.4206967940552, 25.41935647558386],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b02e0dae80694ecdfc24cf37a3e9e07 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71a0da2b7d69c1b5fa6f4fd77c22fbe3);
#
#
#         function geo_json_b1dfc202252b6ddf092beae15b987299_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b1dfc202252b6ddf092beae15b987299_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b1dfc202252b6ddf092beae15b987299_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             const iconOptions = {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             const iconRootAlias = L.AwesomeMarkers
#             opts.icon = new iconRootAlias.Icon(iconOptions)
#
#             let style = geo_json_b1dfc202252b6ddf092beae15b987299_styler(feature)
#             Object.assign(opts.icon.options, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_b1dfc202252b6ddf092beae15b987299_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.ta

# %%
# select reviewers_in similar behavior that are not in different behavior

reviewer_id_similar = similar_behavior['reviewer_id'].unique()
reviewer_id_different = different_behavior['reviewer_id'].unique()

reviewer_id_similar = [x for x in reviewer_id_similar if x not in reviewer_id_different] 

# print number of reviewers with different behavior and with similar behavior

print(len(reviewer_id_different), len(reviewer_id_similar))
# Out:
# 19 40
